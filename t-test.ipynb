# %% [markdown]
# import numpy as np
# from scipy import stats

# %%
scores = [72, 75, 68, 70, 69, 74, 71, 73]

t_stat, p_value = stats.ttest_1samp(scores, 70)

print("T-stat:", t_stat)
print("P-value:", p_value)
